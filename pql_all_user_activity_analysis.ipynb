# %%
import pandas as pd

# %%
df=pd.read_excel('F:\pql_final\pqlv5.xlsx')

# %%
df
# Out:
#       organization_id  added_checkin  added_comment  added_objective  \
# 0                3706              2              0               19
# 1                4323             85              1              163
# 2                 497              3              7                4
# 3                2289            508             11              631
# 4                5411              0              0                0
# ...               ...            ...            ...              ...
# 5357            10883              0              0                0
# 5358            10884              0              0                0
# 5359            10885              0              0                1
# 5360            10886              0              0                0
# 5361            10887              0              0                0
#
#       average_progress_detail  billing_invoice_current  billing_invoice_paid  \
# ...

# %%
y=df['PAID_CUSTOMER']

# %%
import pandas as pd
import numpy as np
import json

# %%
rs=df.corr(method ='pearson') ['PAID_CUSTOMER']

# %%
rs
# Out:
# organization_id                             -0.404496
# added_checkin                                0.231904
# added_comment                                0.219066
# added_objective                              0.295801
# average_progress_detail                     -0.010691
#                                                ...
# First_user_user_id                          -0.246568
# number_of_users_within_lyf_time              0.409708
# PAID_CUSTOMER                                1.000000
# users_within_24_hrs                          0.241367
# count_of_first_user_activity_within_24hrs    0.202460
# Name: PAID_CUSTOMER, Length: 119, dtype: float64

# %%
p=pd.DataFrame(data=rs)

# %%
p
# Out:
#                                            PAID_CUSTOMER
# organization_id                                -0.404496
# added_checkin                                   0.231904
# added_comment                                   0.219066
# added_objective                                 0.295801
# average_progress_detail                        -0.010691
# ...                                                  ...
# First_user_user_id                             -0.246568
# number_of_users_within_lyf_time                 0.409708
# PAID_CUSTOMER                                   1.000000
# users_within_24_hrs                             0.241367
# count_of_first_user_activity_within_24hrs       0.202460
#
# [119 rows x 1 columns]

# %%
p=p.sort_values(by=['PAID_CUSTOMER'],ascending=False)

# %%
p.head(25)
# Out:
#                                          PAID_CUSTOMER
# PAID_CUSTOMER                                 1.000000
# stripe_invoice_finalized                      0.505510
# billing_invoice_paid                          0.486874
# stripe_invoice_payment_succeeded              0.410312
# number_of_users_within_lyf_time               0.409708
# updated_objective                             0.305995
# closed_tour                                   0.303302
# count_of_all_org_activity_within_24hrs        0.298706
# added_objective                               0.295801
# removed_objective                             0.295236
# viewed_okrs                                   0.291955
# user_sign_in_successful                       0.274126
# removed_checkin                               0.255799
# billing_invoice_current                       0.254028
# reordered_objective                           0.252879
# objective_owner_updated_from_quick_view       0.247315
# ...

# %%
col=p.head(25).index

# %%
pd.set_option('display.max_columns', None)

# %%
pf=df

# %%
pf=pf.drop(columns=['PAID_CUSTOMER'])

# %%
df.describe()
# Out:
#        organization_id  added_checkin  added_comment  added_objective  \
# count      5362.000000    5362.000000    5362.000000      5362.000000
# mean       7868.683700      11.595114       0.391458        10.530772
# std        1965.200504     138.742046       4.642997        83.243423
# min           4.000000       0.000000       0.000000         0.000000
# 25%        6518.250000       0.000000       0.000000         0.000000
# 50%        7988.000000       0.000000       0.000000         0.000000
# 75%        9420.750000       0.000000       0.000000         2.000000
# max       10887.000000    6939.000000     192.000000      4552.000000
#
#        average_progress_detail  billing_invoice_current  billing_invoice_paid  \
# count              5362.000000              5362.000000           5362.000000
# mean                  0.001305                 0.011563              0.125140
# std                   0.040952                 0.133317              0.723346
# ...

# %%
a=col[0:1]
b=col[4:25]

# %%
col1=a
col1=col1.append(b)

# %%
con_variables=df[col1]

# %%
x=10

# %%
col1
# Out:
# Index(['PAID_CUSTOMER', 'number_of_users_within_lyf_time', 'updated_objective',
#        'closed_tour', 'count_of_all_org_activity_within_24hrs',
#        'added_objective', 'removed_objective', 'viewed_okrs',
#        'user_sign_in_successful', 'removed_checkin', 'billing_invoice_current',
#        'reordered_objective', 'objective_owner_updated_from_quick_view',
#        'user_sign_up_successful', 'users_within_24_hrs', 'quick_view_opened',
#        'added_checkin', 'added_comment', 'updated_checkin', 'slack_pagination',
#        'viewed_feed', 'slack_command'],
#       dtype='object')

# %%
con_variables
# Out:
#       PAID_CUSTOMER  number_of_users_within_lyf_time  updated_objective  \
# 0                 1                               19                 11
# 1                 1                               38                222
# 2                 0                                8                  4
# 3                 1                              180                312
# 4                 0                                4                  0
# ...             ...                              ...                ...
# 5357              0                                1                  0
# 5358              0                                1                  0
# 5359              0                                1                  0
# 5360              0                                1                  0
# 5361              0                                1                  0
#
#       closed_tour  count_of_all_org_activity_within_24hrs  added_objective  \
# ...

# %%
Cor = con_variables.iloc[:,0:22]
Cor.append(con_variables.iloc[:,4:15])
Cor_matrxi = Cor.corr(method='pearson', min_periods=1)
print(Cor_matrxi)
# Out:
#                                          PAID_CUSTOMER  \
# PAID_CUSTOMER                                 1.000000
# number_of_users_within_lyf_time               0.409708
# updated_objective                             0.305995
# closed_tour                                   0.303302
# count_of_all_org_activity_within_24hrs        0.298706
# added_objective                               0.295801
# removed_objective                             0.295236
# viewed_okrs                                   0.291955
# user_sign_in_successful                       0.274126
# removed_checkin                               0.255799
# billing_invoice_current                       0.254028
# reordered_objective                           0.252879
# objective_owner_updated_from_quick_view       0.247315
# user_sign_up_successful                       0.241367
# users_within_24_hrs                           0.241367
# quick_view_opened                             0.232864
# ...

# %%
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots()
heatmap = ax.pcolor(Cor_matrxi, cmap=plt.cm.Blues, alpha=0.8)
fig = plt.gcf()
fig.set_size_inches(15, 15)
ax.set_frame_on(True)
ax.set_yticks(np.arange(22) + 0.5, minor=False)
ax.set_xticks(np.arange(22) + 0.5, minor=False)
ax.set_xticklabels(col[0:22], minor=False)
ax.set_yticklabels(col[0:22], minor=False)
plt.xticks(rotation=90)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5, 12.5, 13.5, 14.5, 15.5, 16.5, 17.5, 18.5, 19.5, 20.5, 21.5]),
#  <a list of 22 Text xticklabel objects>)

# %%
import seaborn as sb
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(30,30))
ax.set_frame_on(True)
ax.set_yticks(np.arange(x) + 0.5, minor=False)
ax.set_xticks(np.arange(x) + 0.5, minor=False)
ax.set_xticklabels(col[0:22], minor=False)
ax.set_yticklabels(col[0:22], minor=False)
plt.xticks(rotation=90)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
heat_map = sb.heatmap(Cor_matrxi,annot=True,annot_kws={'size':16},cmap='coolwarm')

# %%
plt.show()

# %%
X=con_variables

# %%
y=df['PAID_CUSTOMER']

# %%
features=X.columns

# %%
features
# Out:
# Index(['PAID_CUSTOMER', 'number_of_users_within_lyf_time', 'updated_objective',
#        'closed_tour', 'count_of_all_org_activity_within_24hrs',
#        'added_objective', 'removed_objective', 'viewed_okrs',
#        'user_sign_in_successful', 'removed_checkin', 'billing_invoice_current',
#        'reordered_objective', 'objective_owner_updated_from_quick_view',
#        'user_sign_up_successful', 'users_within_24_hrs', 'quick_view_opened',
#        'added_checkin', 'added_comment', 'updated_checkin', 'slack_pagination',
#        'viewed_feed', 'slack_command'],
#       dtype='object')

# %%
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
# define 
X, y = make_classification(n_samples=1000, n_features=20, n_informative=5, n_redundant=5, random_state=1)
# define the model
model = LogisticRegression()
# fit the model
model.fit(X, y)
# get importance
importance = model.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature:'+ features[i]+', Score: %.5f' % (v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature:PAID_CUSTOMER, Score: 0.16463
# Feature:number_of_users_within_lyf_time, Score: -0.42285
# Feature:updated_objective, Score: -0.05016
# Feature:closed_tour, Score: 0.07497
# Feature:count_of_all_org_activity_within_24hrs, Score: 0.18785
# Feature:added_objective, Score: -0.01988
# Feature:removed_objective, Score: 0.04036
# Feature:viewed_okrs, Score: -0.65955
# Feature:user_sign_in_successful, Score: -0.02573
# Feature:removed_checkin, Score: -0.11265
# Feature:billing_invoice_current, Score: -0.13741
# Feature:reordered_objective, Score: 0.49831
# Feature:objective_owner_updated_from_quick_view, Score: 0.16588
# Feature:user_sign_up_successful, Score: -0.46328
# Feature:users_within_24_hrs, Score: -0.06759
# Feature:quick_view_opened, Score: -0.02814
# Feature:added_checkin, Score: -0.04862
# Feature:added_comment, Score: 0.27069
# Feature:updated_checkin, Score: 0.13491
# Feature:slack_pagination, Score: -0.53934

# %%
con_variables['PAID_CUSTOMER']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# F:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PAID_CUSTOMER'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-199-24eae077618c> in <module>
# ----> 1 con_variables['PAID_CUSTOMER']
#
# ...

# %%
y.shape
# Out:
# (1000,)

# %%
z=df.columns

# %%
y=df['PAID_CUSTOMER']
X=con_variables

del X['PAID_CUSTOMER']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier 
## This line instantiates the model. 
rf = RandomForestClassifier() 
## Fit the model on your training data.
rf.fit(X_train, y_train) 
## And score it on your testing data.
rf.score(X_test, y_test)
# Out:
# 0.9627118644067797

# %%
import pandas as pd
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',                                                                 ascending=False)

# %%
feature_importances
# Out:
#                                          importance
# number_of_users_within_lyf_time            0.365080
# viewed_okrs                                0.106687
# count_of_all_org_activity_within_24hrs     0.102267
# added_objective                            0.095784
# updated_objective                          0.058273
# added_checkin                              0.038853
# user_sign_in_successful                    0.038698
# removed_objective                          0.027085
# closed_tour                                0.025766
# quick_view_opened                          0.024461
# viewed_feed                                0.019345
# users_within_24_hrs                        0.016594
# user_sign_up_successful                    0.016392
# objective_owner_updated_from_quick_view    0.015863
# reordered_objective                        0.013107
# updated_checkin                            0.009364
# slack_pagination                           0.007217
# ...

# %%
z=list(df.columns)

# %%
z.remove('organization_id')

# %%
z.remove('PAID_CUSTOMER')

# %%
z.remove('First_user_user_id')

# %%
z
# Out:
# ['added_checkin',
#  'added_comment',
#  'added_objective',
#  'average_progress_detail',
#  'billing_invoice_current',
#  'billing_invoice_paid',
#  'billing_plan_changed',
#  'browse_menu',
#  'cancellation_request_form_submitted',
#  'cancelled_subscription',
#  'changed_timeperiod',
#  'changed_to_activity_tab_in_quick_view',
#  'changed_to_key_results_tab_in_quick_view',
#  'changed_to_overview_tab_in_quick_view',
#  'clicked_on_scroll_down_button_in_quick_view',
#  'clone_objective',
#  'closed_tour',
#  'created_organization',
#  'flow_completed_appcues',
#  'flow_skipped_appcues',
#  'flow_started_appcues',
#  'followed_entity',
#  'following_menu',
#  'login_attempt_failed_inactive_subscription',
#  'move_objective',
#  'ms_teams_bot_installation',
#  'ms_teams_message',
#  'notifications_menu',
#  'objective_description_updated_from_quick_view',
#  'objective_detailed_view_opened_from_quick_view',
#  'objective_entity_updated_from_quick_view',
# ...

# %%
unwanted_features=['billing_invoice_current',
 'billing_invoice_paid',
 'billing_plan_changed',
'cancellation_request_form_submitted',
 'cancelled_subscription',
     'stripe_invoice_finalized',
 'stripe_invoice_payment_succeeded',
 'subscription_cancelled',
    'billing_invoice_unpaid',
 'stripe_invoice_payment_failed',
'billing_invoice_forgiven',
'canceled_by_customer',
 'cancellation_averted',
    'sign_up_timestamp',
                  'number_of_users_within_lyf_time']

# %%
for i in unwanted_features:
    z.remove(i)

# %%
z
# Out:
# ['added_checkin',
#  'added_comment',
#  'added_objective',
#  'average_progress_detail',
#  'browse_menu',
#  'changed_timeperiod',
#  'changed_to_activity_tab_in_quick_view',
#  'changed_to_key_results_tab_in_quick_view',
#  'changed_to_overview_tab_in_quick_view',
#  'clicked_on_scroll_down_button_in_quick_view',
#  'clone_objective',
#  'closed_tour',
#  'created_organization',
#  'flow_completed_appcues',
#  'flow_skipped_appcues',
#  'flow_started_appcues',
#  'followed_entity',
#  'following_menu',
#  'login_attempt_failed_inactive_subscription',
#  'move_objective',
#  'ms_teams_bot_installation',
#  'ms_teams_message',
#  'notifications_menu',
#  'objective_description_updated_from_quick_view',
#  'objective_detailed_view_opened_from_quick_view',
#  'objective_entity_updated_from_quick_view',
#  'objective_owner_updated_from_quick_view',
#  'objective_tags_updated_from_quick_view',
#  'objective_title_updated_from_quick_view',
#  'quick_checked_in_okrs',
# ...

# %%
len(z)
# Out:
# 102

# %%
X=df[z]

# %%
X
# Out:
#       added_checkin  added_comment  added_objective  average_progress_detail  \
# 0                 2              0               19                        0
# 1                85              1              163                        0
# 2                 3              7                4                        0
# 3               508             11              631                        0
# 4                 0              0                0                        0
# ...             ...            ...              ...                      ...
# 5357              0              0                0                        0
# 5358              0              0                0                        0
# 5359              0              0                1                        0
# 5360              0              0                0                        0
# 5361              0              0                0                        0
#
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=0.33, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier 
## This line instantiates the model. 
rf = RandomForestClassifier() 
## Fit the model on your training data.
rf.fit(X_train, y_train) 
## And score it on your testing data.
rf.score(X_test, y_test)
# Out:
# 0.9384180790960452

# %%
import pandas as pd
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = X_train.columns,
                                    columns=['importance']).sort_values('importance',                                                                 ascending=False)

# %%
feature_importances.head(30)
# Out:
#                                                 importance
# viewed_okrs                                       0.133835
# count_of_all_org_activity_within_24hrs            0.107718
# added_objective                                   0.090379
# count_of_first_user_activity_within_24hrs         0.059475
# added_checkin                                     0.051819
# updated_objective                                 0.050878
# user_sign_in_successful                           0.040037
# quick_view_opened                                 0.036880
# removed_objective                                 0.034672
# viewed_feed                                       0.034371
# created_organization                              0.033296
# closed_tour                                       0.033279
# reordered_objective                               0.028890
# objective_owner_updated_from_quick_view           0.022903
# users_within_24_hrs                               0.020717
# ...

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred=rf.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[1563,   35],
#        [  74,   98]], dtype=int64)

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test, y_pred) )
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97      1598
#            1       0.74      0.57      0.64       172
#
#     accuracy                           0.94      1770
#    macro avg       0.85      0.77      0.80      1770
# weighted avg       0.93      0.94      0.93      1770

# %%
pl=df[['viewed_okrs','added_objective','updated_objective','viewed_feed',
'added_checkin',
'removed_objective',
'closed_tour',
'quick_view_opened',
'reordered_objective',
'users_within_24_hrs',
'objective_owner_updated_from_quick_view']]

# %%
out=pl.describe()

# %%
out.to_excel('F:\pql_final\descriptive.xlsx')

# %%
from autoplotter import run_app

# %%
run_app(pl)
# Out:
#         <iframe
#             width="1136"
#             height="650"
#             src="http://127.0.0.1:12345/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
pl
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-3a85e518c4fc> in <module>
# ----> 1 pl
#
# NameError: name 'pl' is not defined
